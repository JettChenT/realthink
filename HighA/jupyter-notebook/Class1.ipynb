# %%
# platform
# get to know the information about the operation system
import platform

# %%
platform.platform()
# Out:
# 'Darwin-18.5.0-x86_64-i386-64bit'

# %%
platform.version()
# Out:
# 'Darwin Kernel Version 18.5.0: Mon Mar 11 20:40:32 PDT 2019; root:xnu-4903.251.3~3/RELEASE_X86_64'

# %%
platform.architecture()
# Out:
# ('64bit', '')

# %%
platform.machine()
# Out:
# 'x86_64'

# %%
platform.node()
# Out:
# 'Jetts-MacBook-Pro.local'

# %%
platform.processor()
# Out:
# 'i386'

# %%
un = platform.uname()
print(un.system)
# Out:
# Darwin

# %%
# get information of the python version

# %%
platform.python_build()
# Out:
# ('default', 'Mar 27 2019 16:54:48')

# %%
platform.python_compiler()
# Out:
# 'Clang 4.0.1 (tags/RELEASE_401/final)'

# %%
platform.python_branch()
# Out:
# ''

# %%
platform.python_implementation()
# Out:
# 'CPython'

# %%
platform.python_version_tuple()
# Out:
# ('3', '7', '3')

# %%
platform.python_version()
# Out:
# '3.7.3'

# %%
import psutil

# %%
psutil.test()
# Out:
# USER         PID %MEM     VSZ     RSS TTY           START    TIME  COMMAND
# root           0    ?       ?       ? ?             Sep20   00:00  kernel_task
# root           1    ?       ?       ? ?             Sep20   00:00  launchd
# root          41    ?       ?       ? ?             Sep20   00:00  syslogd
# root          42    ?       ?       ? ?             Sep20   00:00  UserEventAgent
# root          45    ?       ?       ? ?             Sep20   00:00  uninstalld
# root          46    ?       ?       ? ?             Sep20   00:00  kextd
# root          47    ?       ?       ? ?             Sep20   00:00  fseventsd
# _appleeven    52    ?       ?       ? ?             Sep20   00:00  appleeventsd
# root          53    ?       ?       ? ?             Sep20   00:00  systemstats
# root          55    ?       ?       ? ?             Sep20   00:00  configd
# root          56    ?       ?       ? ?             Sep20   00:00  powerd
# root          59    ?       ?       ? ?             Sep20   00:00  logd
# root          66    ?       ?       ? ?             Sep20   00:00  mds
# root          67    ?       ?       ? ?             Sep20   00:00  com.nordvpn.osx.
# root          69    ?       ?       ? ?             Sep20   00:00  diskarbitrationd
# root          72    ?       ?       ? ?             Sep20   00:00  backupd-helper
# root          74    ?       ?       ? ?             Sep20   00:00  hamachid
# root          78    ?       ?       ? ?             Sep20   00:00  opendirectoryd
# root          79    ?       ?       ? ?             Sep20   00:00  apsd
# root          80    ?       ?       ? ?             Sep20   00:00  nbstated
# root          81    ?       ?       ? ?             Sep20   00:00  launchservicesd
# _timed        82    ?       ?       ? ?             Sep20   00:00  timed
# root          83    ?       ?       ? ?             Sep20   00:00  securityd
# _usbmuxd      84    ?       ?       ? ?             Sep20   00:00  usbmuxd
# root          88    ?       ?       ? ?             Sep20   00:00  autofsd
# _displaypo    89    ?       ?       ? ?             Sep20   00:00  displaypolicyd
# root          90    ?       ?       ? ?             Sep20   00:00  dasd
# root          94  0.3 5036564   28600 ?             Sep20   00:50  loginwindow
# root          95    ?       ?       ? ?             Sep20   00:00  logind
# root          96    ?       ?       ? ?             Sep20   00:00  revisiond
# root          97    ?       ?       ? ?             Sep20   00:00  KernelEventAgent
# root          99    ?       ?       ? ?             Sep20   00:00  bluetoothd
# _hidd        100    ?       ?       ? ?             Sep20   00:00  hidd
# root         102    ?       ?       ? ?             Sep20   00:00  corebrightnessd
# root         103    ?       ?       ? ?             Sep20   00:00  AirPlayXPCHelper
# root         104    ?       ?       ? ?             Sep20   00:00  notifyd
# _distnote    106    ?       ?       ? ?             Sep20   00:00  distnoted
# root         107    ?       ?       ? ?             Sep20   00:00  cfprefsd
# root         110    ?       ?       ? ?             Sep20   00:00  authd
# root         115    ?       ?       ? ?             Sep20   00:00  coreservicesd
# root         125    ?       ?       ? ?             Sep20   00:00  com.apple.ctkpcs
# root         127    ?       ?       ? ?             Sep20   00:00  trustd
# root         130    ?       ?       ? ?             Sep20   00:00  contextstored
# root         134    ?       ?       ? ?             Sep20   00:00  airportd
# _coreaudio   136    ?       ?       ? ?             Sep20   00:00  coreaudiod
# root         137    ?       ?       ? ?             Sep20   00:00  lsd
# root         140    ?       ?       ? ?             Sep20   00:00  syspolicyd
# root         152    ?       ?       ? ?             Sep20   00:00  awdd
# _nsurlsess   170    ?       ?       ? ?             Sep20   00:00  nsurlsessiond
# _mdnsrespo   173    ?       ?       ? ?             Sep20   00:00  mDNSResponder
# _networkd    175    ?       ?       ? ?             Sep20   00:00  symptomsd
# root         176    ?       ?       ? ?             Sep20   00:00  mDNSResponderHel
# root         179    ?       ?       ? ?             Sep20   00:00  apfsd
# root         181    ?       ?       ? ?             Sep20   00:00  WindowServer
# root         192    ?       ?       ? ?             Sep20   00:00  watchdogd
# root         193    ?       ?       ? ?             Sep20   00:00  thermald
# root         200    ?       ?       ? ?             Sep20   00:00  mds_stores
# root         201    ?       ?       ? ?             Sep20   00:00  CVMServer
# root         203    ?       ?       ? ?             Sep20   00:00  tccd
# _atsserver   219    ?       ?       ? ?             Sep20   00:00  fontd
# root         224    ?       ?       ? ?             Sep20   00:00  com.apple.Perfor
# root         234    ?       ?       ? ?             Sep20   00:00  distnoted
# _locationd   240    ?       ?       ? ?             Sep20   00:00  cfprefsd
# root         242    ?       ?       ? ?             Sep20   00:00  sharedfilelistd
# root         248    ?       ?       ? ?             Sep20   00:00  systemstats
# _cmiodalas   250    ?       ?       ? ?             Sep20   00:00  AppleCameraAssis
# root         253    ?       ?       ? ?             Sep20   00:00  com.apple.Ambien
# jettchen     260    ? 4307820    3636 ?             Sep20   01:07  cfprefsd
# root         261    ?       ?       ? ?             Sep20   00:00  securityd_servic
# jettchen     262  0.1 4334540    5652 ?             Sep20   00:48  UserEventAgent
# jettchen     264  0.1 4305856    4304 ?             Sep20   01:03  distnoted
# jettchen     266  0.1 4346340    6480 ?             Sep20   00:16  CommCenter
# jettchen     267  0.1 4353476    9044 ?             Sep20   02:21  trustd
# jettchen     268  0.1 4341992    7292 ?             Sep20   00:16  lsd
# jettchen     269  0.1 4336164    6252 ?             Sep20   00:06  rapportd
# jettchen     270  0.1 4343592    8108 ?             Sep20   00:11  identityservicesd
# jettchen     272  0.1 4337144    4268 ?             Sep20   00:02  sharedfilelistd
# jettchen     276  0.2 4362240   14112 ?             Sep20   00:30  cloudd
# jettchen     280  0.3 4440732   21116 ?             Sep20   01:13  accountsd
# jettchen     281  0.1 4337392    7096 ?             Sep20   00:13  tccd
# jettchen     282  0.1 4334240    5480 ?             Sep20   00:02  imagent
# root         284    ?       ?       ? ?             Sep20   00:00  wirelessproxd
# jettchen     285  0.1 4341724    5112 ?             Sep20   00:06  akd
# jettchen     287  0.1 4340740    8508 ?             Sep20   00:05  usernoted
# jettchen     289    ? 4304816    3496 ?             Sep20   00:05  ContactsAccountsService
# jettchen     291  0.1 4335976    6252 ?             Sep20   00:21  secinitd
# jettchen     292  0.1 4341528    7676 ?             Sep20   00:26  nsurlsessiond
# root         293    ?       ?       ? ?             Sep20   00:00  CrashReporterSup
# jettchen     294  0.3 5255256   27660 ?             Sep20   00:32  NotificationCenter
# jettchen     296    ? 4306268    1788 ?             Sep20   00:03  pboard
# jettchen     298    ? 4337868    2800 ?             Sep20   00:02  IMRemoteURLConnectionAgent
# jettchen     299  0.1 4339876    5496 ?             Sep20   00:28  nsurlstoraged
# jettchen     300  0.3 4369956   25536 ?             Sep20   01:11  sharingd
# jettchen     301  0.1 4337172    4820 ?             Sep20   00:05  homed
# jettchen     303  0.1 4335220    5880 ?             Sep20   00:52  fontd
# jettchen     308    ? 4589416    3852 ?             Sep20   00:13  WiFiAgent
# jettchen     309    ? 4333240     512 ?             Sep20   00:00  familycircled
# jettchen     311    ? 4332804    1756 ?             Sep20   00:01  IMRemoteURLConnectionAgent
# jettchen     312  0.1 4336500    5212 ?             Sep20   00:05  imklaunchagent
# jettchen     315  0.1 4335448    6556 ?             Sep20   00:15  pkd
# root         317    ?       ?       ? ?             Sep20   00:00  spindump
# jettchen     319  0.1 4334308    4336 ?             Sep20   00:27  useractivityd
# root         325    ?       ?       ? ?             Sep20   00:00  SubmitDiagInfo
# jettchen     326    ? 4867632    4140 ?             Sep20   00:09  PAH_Extension
# jettchen     328    ? 4304664     608 ?             Sep20   00:00  mediaremoteagent
# jettchen     332  0.4 4394612   33720 ?             Sep20   00:58  assistantd
# jettchen     333  0.1 4336780    7360 ?             Sep20   00:08  bird
# jettchen     337    ? 4306488    2796 ?             Sep20   00:05  storeaccountd
# jettchen     339  0.3 5071668   28400 ?             Sep20   02:24  Dock
# jettchen     340  0.2 5040936   19328 ?             Sep20   07:04  SystemUIServer
# jettchen     341  1.5 5296020  123448 ?             Sep20   06:27  Finder
# jettchen     349  0.4 5535844   36260 ?             Sep20   00:35  Spotlight
# jettchen     353  0.1 4372892    7900 ?             Sep20   01:09  commerce
# root         355    ?       ?       ? ?             Sep20   00:00  filecoordination
# jettchen     367    ? 4371532    3036 ?             Sep20   00:07  ACCFinderSync
# jettchen     368    ? 4332392    2096 ?             Sep20   00:05  WiFiProxy
# jettchen     373  0.1 4949284    5920 ?             Sep20   00:08  com.apple.dock.extra
# _softwareu   384    ?       ?       ? ?             Sep20   00:00  softwareupdated
# root         391    ?       ?       ? ?             Sep20   00:00  suhelperd
# root         401    ?       ?       ? ?             Sep20   00:00  taskgated
# jettchen     406    ? 4332320    3740 ?             Sep20   00:04  fileproviderd
# jettchen     407  0.1 4384848   12328 ?             Sep20   00:11  studentd
# jettchen     409  0.1 4882148    6416 ?             Sep20   00:22  LocationMenu
# jettchen     455    ? 4333128    1680 ?             Sep20   00:02  mdwrite
# jettchen     476    ? 4333964    3076 ?             Sep20   00:01  backgroundtaskmanagementagent
# jettchen     480  0.1 4974756    7764 ?             Sep20   02:42  Magnet
# jettchen     481  0.4 7744624   34024 ?             Sep20   01:33  CleanMyMac X Menu
# jettchen     482  0.2 6100688   15796 ?             Sep20   14:21  CheatSheet
# jettchen     483  0.2 4939752   17096 ?             Sep20   03:44  NightOwl
# _fpsd        486    ?       ?       ? ?             Sep20   00:00  adid
# jettchen     521    ? 4287720       8 ?             Sep20   00:00  ipcserver
# jettchen     529  0.1 4361592    5584 ?             Sep20   00:01  com.apple.CloudPhotosConfiguration
# jettchen     531    ? 4307936     588 ?             Sep20   00:00  crashpad_handler
# jettchen     553    ? 4332488     656 ?             Sep20   00:00  storelegacy
# jettchen     575  0.1 4401560   12020 ?             Sep20   02:25  CleanMyMac X HealthMonitor
# jettchen     578    ? 4374488    3536 ?             Sep20   00:08  photolibraryd
# _softwareu   625    ?       ?       ? ?             Sep20   00:00  cfprefsd
# _softwareu   626    ?       ?       ? ?             Sep20   00:00  distnoted
# jettchen     636    ? 4304832       8 ?             Sep20   00:00  corespeechd
# jettchen     638  0.1 4336688    5908 ?             Sep20   00:11  SogouServices
# jettchen     639    ? 4331356    1248 ?             Sep20   00:00  SocialPushAgent
# jettchen     642  0.1 4368280   11064 ?             Sep20   01:37  HP Product Research
# jettchen     645    ? 4333792    2244 ?             Sep20   00:00  icdd
# jettchen     646  0.1 4381420   12460 ?             Sep20   11:45  HP Device Monitor
# jettchen     651    ? 4865408    2816 ?             Sep20   00:06  AirPlayUIAgent
# jettchen     654    ? 4333144    2132 ?             Sep20   00:17  cloudpaird
# jettchen     656  0.1 4358476    5392 ?             Sep20   00:08  nbagent
# jettchen     657    ? 4333220    3848 ?             Sep20   00:06  diagnostics_agent
# jettchen     672  0.1 4343080    6668 ?             Sep20   00:04  storeassetd
# jettchen     677    ? 4353256    3824 ?             Sep20   00:06  LaterAgent
# jettchen     680  0.2 4998356   18124 ?             Sep20   00:23  ShadowsocksX-NG
# root         721    ?       ?       ? ?             Sep20   00:00  system_installd
# jettchen     723  0.1 4389588    9156 ?             Sep20   11:27  storedownloadd
# root         726    ?       ?       ? ?             Sep20   00:00  installd
# _spotlight   848    ?       ?       ? ?             Sep20   00:00  distnoted
# jettchen     885  0.1 4383124    5124 ?             Sep20   00:01  com.apple.speech.speechsynthesisd
# root        1083    ?       ?       ? ?             Sep20   00:00  storeinstalld
# jettchen    1160  0.7 5306652   57600 ?             Sep20   01:57  SCIM_Extension
# jettchen    1173    ? 4590912    3128 ?             Sep20   00:06  corespotlightd
# jettchen    1185    ? 4333448     784 ?             Sep20   00:00  mdworker
# _spotlight  1186    ?       ?       ? ?             Sep20   00:00  mdworker
# jettchen    1267    ? 4281160      64 ?             Sep20   00:00  ssh-agent
# jettchen    1403    ? 4331552    1944 ?             Sep20   00:00  assertiond
# jettchen    1801    ? 4971004     888 ?             Sep20   00:04  UIKitSystem
# jettchen    2018  0.1 4962592    4268 ?             Sep20   00:06  universalAccessAuthWarn
# _fpsd       2429    ?       ?       ? ?             Sep20   00:00  fpsd
# jettchen    3228    ? 4332168    2148 ?             Sep20   00:00  IMAutomaticHistoryDeletionAgent
# jettchen    3964  0.1 4440304    4756 ?             Sep20   00:07  PowerChime
# jettchen    8420  3.6 5834624  300728 ?             Sep21   12:18  Google Chrome
# jettchen    8422    ? 4307964     924 ?             Sep21   00:00  chrome_crashpad_handler
# jettchen    8451  0.7 5332496   62828 ?             Sep21   16:36  Google Chrome Helper (GPU)
# jettchen    8452  0.3 4584296   28796 ?             Sep21   09:26  Google Chrome Helper
# jettchen    8461  0.5 4839228   44104 ?             Sep21   00:57  Google Chrome Helper (Renderer)
# jettchen    8462  0.7 4828680   56316 ?             Sep21   00:14  Google Chrome Helper (Renderer)
# jettchen    8463  2.1 6139592  173532 ?             Sep21   03:09  Google Chrome Helper (Renderer)
# jettchen    8464  0.2 4757372   13724 ?             Sep21   00:02  Google Chrome Helper (Renderer)
# jettchen    8465  0.5 4788156   41892 ?             Sep21   00:47  Google Chrome Helper (Renderer)
# jettchen    8466  0.2 4755580   13668 ?             Sep21   00:02  Google Chrome Helper (Renderer)
# jettchen   11526    ? 4698684     724 ?             Sep21   00:00  Code - Insiders Helper (Renderer)
# jettchen   11614    ? 4698172     764 ?             Sep21   00:00  Code - Insiders Helper (Renderer)
# jettchen   12088    ? 4333436    1436 ?             Sep21   00:07  MIDIServer
# jettchen   12397    ? 4698428    1100 ?             Sep21   00:00  Code - Insiders Helper (Renderer)
# jettchen   12858  0.1 4543904    4228 ?             Sep21   03:04  Google Chrome Helper
# _locationd 13786    ?       ?       ? ?             Sep21   00:00  distnoted
# jettchen   17425  0.1 4389784    7624 ?             Sep21   00:13  cloudphotosd
# jettchen   17430  0.2 4352088   13804 ?             Sep21   00:21  routined
# jettchen   17436    ? 4344840    3148 ?             Sep21   00:05  Keychain Circle Notification
# jettchen   17456    ? 4334696    3792 ?             Sep21   00:15  ViewBridgeAuxiliary
# jettchen   17460    ? 4336368    4060 ?             Sep21   00:49  deleted
# _assetcach 17462    ?       ?       ? ?             Sep21   00:00  AssetCache
# root       17463    ?       ?       ? ?             Sep21   00:00  coresymbolicatio
# root       17464    ?       ?       ? ?             Sep21   00:00  sysdiagnose
# root       17465    ?       ?       ? ?             Sep21   00:00  aslmanager
# root       17466    ?       ?       ? ?             Sep21   00:00  mobileassetd
# jettchen   17467    ? 4331536    1336 ?             Sep21   00:00  com.apple.quicklook.ThumbnailsAgent
# jettchen   17473  0.1 4345204    8076 ?             Sep21   00:16  secd
# jettchen   17474    ? 4331916    2020 ?             Sep21   00:00  ProtectedCloudKeySyncing
# jettchen   17475  0.1 4387152    5180 ?             Sep21   00:01  com.apple.MediaLibraryService
# jettchen   17496  0.1 4349080    5900 ?             Sep21   00:11  Siri
# jettchen   17503    ? 4305260    1156 ?             Sep21   00:11  com.apple.hiservices-xpcservice
# _gamecontr 17504    ?       ?       ? ?             Sep21   00:00  gamecontrollerd
# jettchen   17505  0.4 4709436   30856 ?             Sep21   00:13  AppleSpell
# jettchen   17507  0.2 4485652   19896 ?             Sep21   00:26  suggestd
# jettchen   17508  0.4 4387684   32084 ?             Sep21   01:56  CalendarAgent
# jettchen   17509  0.2 4344384   13512 ?             Sep21   00:16  CalNCService
# jettchen   17545  0.3 4943000   26824 ?             Sep21   00:09  SiriNCService
# root       17585    ?       ?       ? ?             Sep21   00:00  nehelper
# jettchen   18171    ? 4305552    1008 ?             Sep21   00:00  SidecarRelay
# jettchen   18503  0.2 4380516   15388 ?             Sep21   00:16  photoanalysisd
# jettchen   18505  0.1 4348020    5568 ?             Sep21   00:04  com.apple.geod
# jettchen   18517    ? 4337548     836 ?             Sep21   00:00  com.apple.CommerceKit.TransactionService
# root       18578    ?       ?       ? ?             Sep21   00:00  periodic-wrapper
# jettchen   18580  0.1 4343504    5748 ?             Sep21   00:02  parsecd
# jettchen   18657    ? 4340964    4184 ?             Sep21   00:04  knowledge-agent
# jettchen   18712  0.1 4889680    5376 ?             Sep21   00:07  OSDUIHelper
# jettchen   19041  1.1 6687136   89700 ?             Sep21   06:07  Spark
# jettchen   19047  0.2 4415244   20404 ?             Sep21   01:10  assistant_service
# jettchen   19174    ? 4367008    3120 ?             Sep21   00:06  ACCFinderSync
# jettchen   19229    ? 4333184    1816 ?             Sep21   00:00  AlertNotificationService
# jettchen   19262  0.1 4350148    4744 ?             Sep21   00:10  CoreLocationAgent
# root       19679    ?       ?       ? ?             Sep21   00:00  diskmanagementd
# root       19713    ?       ?       ? ?             Sep21   00:00  storagekitd
# jettchen   19899    ? 4335524    3100 ?             Sep21   00:25  SafariBookmarksSyncAgent
# jettchen   20028    ? 106266416    1504 ?             Sep21   00:03  com.apple.WebKit.WebContent
# jettchen   20029    ? 4348488    1560 ?             Sep21   00:06  com.apple.WebKit.Networking
# jettchen   20030    ? 106352192    1552 ?             Sep21   00:04  com.apple.WebKit.WebContent
# root       20185    ?       ?       ? ?             Sep21   00:00  cupsd
# jettchen   20551    ? 4306296     176 ?             Sep21   00:00  USBAgent
# jettchen   20635  0.2 106242256   13508 ?             Sep21   00:04  com.apple.WebKit.WebContent
# jettchen   20636    ? 4342188    2376 ?             Sep21   00:04  com.apple.WebKit.Networking
# jettchen   20639  0.1 106256248    6432 ?             Sep21   00:05  com.apple.WebKit.WebContent
# jettchen   20640    ? 4342188    1984 ?             Sep21   00:04  com.apple.WebKit.Networking
# jettchen   20727    ? 4897580    3456 ?             Sep21   00:03  QuickLookUIService
# jettchen   26923  0.3 4772444   23780 ?             Sep22   00:02  Google Chrome Helper (Renderer)
# jettchen   27912  0.1 4350548    5236 ?             Sep22   00:04  storeuid
# jettchen   32056    ? 4305288    1316 ?             Sep22   00:00  DiskUnmountWatcher
# jettchen   36522  0.1 4989160    9980 ?             Sep22   00:12  Amphetamine
# root       36554    ?       ?       ? ?             Sep22   00:00  rtcreportingd
# jettchen   43306  0.1 4346856    4612 ?             Sep23   00:04  talagent
# root       43411    ?       ?       ? ?             Sep23   00:00  sandboxd
# root       45911    ?       ?       ? ?             Sep23   00:00  WirelessRadioMan
# jettchen   45914  0.4 4343096   33156 ?             Sep23   00:03  soagent
# root       45934    ?       ?       ? ?             Sep23   00:00  mediaremoted
# root       45945    ?       ?       ? ?             Sep23   00:00  keybagd
# root       45946    ?       ?       ? ?             Sep23   00:00  com.apple.CodeSi
# jettchen   46088  0.1 4341848    5680 ?             Sep23   00:00  atsd
# root       46091    ?       ?       ? ?             Sep23   00:00  systemsoundserve
# root       46092    ?       ?       ? ?             Sep23   00:00  AudioComponentRe
# jettchen   46108    ? 4286804     612 ?             Sep23   00:00  privoxy
# root       46110    ?       ?       ? ?             Sep23   00:00  amfid
# root       46165    ?       ?       ? ?             Sep23   00:00  sysmond
# root       46217    ?       ?       ? ?             Sep23   00:00  coreduetd
# jettchen   46224  0.8 4489256   68964 ?             Sep23   00:26  iconservicesagent
# _iconservi 46225    ?       ?       ? ?             Sep23   00:00  iconservicesd
# jettchen   46234  0.2 4361940   19268 ?             Sep23   00:00  com.apple.photomodel
# jettchen   46241  0.1 4335864    6548 ?             Sep23   00:00  ScopedBookmarkAgent
# jettchen   46249  0.1 4306324   11100 ?             Sep23   00:00  silhouette
# jettchen   46258  0.3 4418416   24668 ?             Sep23   00:07  media-indexer
# jettchen   46259  0.1 4336136    9984 ?             Sep23   00:00  com.apple.iTunesLibraryService
# jettchen   46267  0.4 5032196   30080 ?             Sep23   00:12  com.apple.appkit.xpc.openAndSavePanelService
# jettchen   46269  0.1 4843264   11076 ?             Sep23   00:00  MTLCompilerService
# jettchen   46271  0.1 4339536    5516 ?             Sep23   00:00  ContextService
# jettchen   46311  0.1 4335956    7448 ?             Sep23   00:00  AudioComponentRegistrar
# jettchen   46312  0.1 4304868    8328 ?             Sep23   00:00  com.apple.audio.SandboxHelper
# root       46323    ?       ?       ? ?             Sep23   00:00  ctkahp
# root       46324    ?       ?       ? ?             Sep23   00:00  coreauthd
# jettchen   46325  0.1 4306048    8992 ?             Sep23   00:00  ctkahp
# jettchen   46326  0.1 4306484    8720 ?             Sep23   00:00  ctkd
# _ctkd      46327    ?       ?       ? ?             Sep23   00:00  ctkd
# _analytics 46328    ?       ?       ? ?             Sep23   00:00  analyticsd
# jettchen   46358  0.1 4305492    5368 ?             Sep23   00:00  CloudKeychainProxy
# jettchen   46359  0.1 4304900    8488 ?             Sep23   00:00  followupd
# root       46363    ?       ?       ? ?             Sep23   00:00  com.apple.Accoun
# root       46388    ?       ?       ? ?             Sep23   00:00  dprivacyd
# jettchen   46389  0.1 4344772    8040 ?             Sep23   00:02  com.apple.Safari.SafeBrowsing.Service
# jettchen   46390  0.1 4339444    7352 ?             Sep23   00:00  AssetCacheLocatorService
# root       46439    ?       ?       ? ?             Sep23   00:00  ReportCrash
# jettchen   46489  0.1 4291404    5312 ?             Sep23   00:00  spindump_agent
# jettchen   46862  0.2 4308724   15868 ?             Sep23   00:00  IMDPersistenceAgent
# jettchen   46883  0.1 4336152    9856 ?             Sep23   00:00  networkserviceproxy
# jettchen   47369  0.1 4305932   10700 ?             Sep23   00:00  softwareupdate_notify_agent
# root       51289    ?       ?       ? ?             Sep24   00:00  mobileactivation
# root       51449    ?       ?       ? ?             Sep24   00:00  nesessionmanager
# root       51487    ?       ?       ? ?             Sep24   00:00  iconservicesagen
# jettchen   51488  0.1 4340056    8140 ?             Sep24   00:00  pbs
# _spotlight 51493    ?       ?       ? ?             Sep24   00:00  trustd
# jettchen   55265  0.3 4304916   26332 ?             Sep24   00:00  EscrowSecurityAlert
# jettchen   55268  0.2 4345084   16112 ?             Sep24   00:01  com.apple.sbd
# jettchen   55273  0.1 4304660    8200 ?             Sep24   00:00  cdpd
# _locationd 55279    ?       ?       ? ?             Sep24   00:00  com.apple.geod
# _locationd 55280    ?       ?       ? ?             Sep24   00:00  secinitd
# _locationd 55281    ?       ?       ? ?             Sep24   00:00  trustd
# _nsurlstor 55282    ?       ?       ? ?             Sep24   00:00  nsurlstoraged
# _datadetec 55310    ?       ?       ? ?             Sep24   00:00  DataDetectorsSou
# jettchen   56131  0.3 4343340   20992 ?             Sep24   00:01  fmfd
# jettchen   56136  0.1 4331548    6444 ?             Sep24   00:00  CMFSyncAgent
# jettchen   56697  0.1 4336808    6484 ?             Sep24   00:00  swcd
# jettchen   56698  0.1 4334124   10960 ?             Sep24   00:00  ContainerMetadataExtractor
# jettchen   59198  0.1 4336136   10200 ?             Sep24   00:00  com.apple.iTunesLibraryService
# jettchen   59209  0.2 4350720   19476 ?             Sep24   00:03  appstoreagent
# jettchen   59213  0.2 4342568   15212 ?             Sep24   00:00  keyboardservicesd
# jettchen   59215  0.2 4332768   13568 ?             Sep24   00:00  com.apple.siri.ClientFlow.ClientScripter
# jettchen   59219  0.1 4305104    8908 ?             Sep24   00:00  coreauthd
# jettchen   59222  0.2 4332316   13100 ?             Sep24   00:00  siriknowledged
# jettchen   59223  0.1 4331972   10400 ?             Sep24   00:00  FMIPClientXPCService
# jettchen   59227  0.2 4335228   13172 ?             Sep24   00:00  mapspushd
# jettchen   59284  0.2 4335364   15768 ?             Sep24   00:00  com.apple.siri-distributed-evaluation
# root       59525    ?       ?       ? ?             Sep24   00:00  periodic-wrapper
# jettchen   59633  0.2 4337964   17704 ?             Sep24   00:01  adprivacyd
# jettchen   59680  0.3 5197068   26708 ?             Sep24   00:04  SogouInput
# root       62390    ?       ?       ? ?             Sep24   00:00  smd
# jettchen   64414  0.1 4345572    5952 ?             Sep24   00:03  VTDecoderXPCService
# jettchen   65477  0.1 4843712    9264 ?             Sep24   00:00  MTLCompilerService
# _softwareu 65950    ?       ?       ? ?             Sep24   00:00  softwareupdate_d
# _spotlight 68721    ?       ?       ? ?             Sep25   00:00  mdworker_shared
# jettchen   74068  0.2 4368164   17932 ?             Sep25   00:10  LogMeIn Hamachi Menubar
# jettchen   77552  0.2 4321080   20964 ?             Sep25   00:18  mdworker_shared
# jettchen   78020  0.5 5106496   39212 ?             Sep25   00:02  LookupViewService
# jettchen   78027  0.1 4331988    5496 ?             Sep25   00:00  com.apple.DictionaryServiceHelper
# _locationd 78876    ?       ?       ? ?             Sep25   00:00  locationd
# jettchen   78922  0.1 4296936    8340 ?             Sep25   00:00  com.apple.audio.SandboxHelper
# jettchen   78923  0.2 4370332   14296 ?             Sep25   00:00  com.apple.siri.ClientFlow.ClientScripter
# root       78959    ?       ?       ? ?             Sep25   00:00  GSSCred
# jettchen   78971  0.2 4347812   13352 ?             Sep25   00:01  AdobeIPCBroker
# jettchen   78972  0.1 4307312    5104 ?             Sep25   00:00  colorsync.useragent
# root       78973    ?       ?       ? ?             Sep25   00:00  colorsyncd
# jettchen   78989  0.4 4991564   30072 ?             Sep25   00:00  Adobe CCXProcess.app
# jettchen   78998  0.1 4305288    7964 ?             Sep25   00:00  ReportCrash
# _windowser 79003    ?       ?       ? ?             Sep25   00:00  MTLCompilerServi
# root       79534    ?       ?       ? ?             Sep25   00:00  PerfPowerService
# jettchen   79629  0.6 5214972   46744 ?             Sep25   00:52  iTerm2
# jettchen   80217  0.3 4969148   22564 ?             Sep25   00:01  sublime_merge
# _netbios   81055    ?       ?       ? ?             16:40   00:00  netbiosd
# root       81265    ?       ?       ? ?             16:45   00:00  findmydeviced
# root       81266    ?       ?       ? ?             16:45   00:00  FindMyMacd
# jettchen   83430  0.2 4314880   15032 /dev/ttys000  19:48   00:00  iTerm2
# jettchen   83431    ?       ?       ? /dev/ttys000  19:48   00:00  login
# jettchen   83432    ? 4297556    1380 /dev/ttys000  19:48   00:01  zsh
# jettchen   83478    ? 4279288     896 /dev/ttys000  19:48   00:00  zsh
# jettchen   83479    ? 4293672     760 /dev/ttys000  19:48   00:00  gitstatusd-darwin-x86_64
# jettchen   83846  1.2 5408220  103856 ?             19:57   03:24  Sublime Text
# jettchen   83847  0.2 4382036   17184 ?             19:57   00:04  plugin_host
# jettchen   84306  0.2 4343776   12996 ?             20:04   00:02  mdworker_shared
# jettchen   84307  0.2 4323072   15040 /dev/ttys002  20:04   00:00  iTerm2
# jettchen   84308    ?       ?       ? /dev/ttys002  20:04   00:00  login
# jettchen   84309    ? 4297524    1368 /dev/ttys002  20:04   00:01  zsh
# jettchen   84356    ? 4296696     896 /dev/ttys002  20:04   00:00  zsh
# jettchen   84357    ? 4293672     760 /dev/ttys002  20:04   00:00  gitstatusd-darwin-x86_64
# jettchen   84379  0.4 4320532   31856 /dev/ttys002  20:05   00:04  python3.7
# jettchen   84389  2.9 5094644  239100 ?             20:05   00:23  Google Chrome Helper (Renderer)
# jettchen   84409  0.4 4330156   31076 ?             20:05   00:01  python3.7
# jettchen   84562  2.1 5363744  172360 ?             20:10   00:18  Google Chrome Helper (Renderer)
# jettchen   84563  1.3 5224692  110260 ?             20:10   00:32  Google Chrome Helper (Renderer)
# jettchen   84572  0.6 4787676   50948 ?             20:10   00:01  Google Chrome Helper (Renderer)
# jettchen   84587  0.2 4315784   17876 ?             20:10   00:03  mdworker_shared
# jettchen   84590  0.2 4315552   18784 ?             20:10   00:02  mdworker_shared
# jettchen   85150  1.4 4982940  114608 ?             20:23   00:09  Google Chrome Helper (Renderer)
# jettchen   85152  1.6 5000680  131668 ?             20:23   00:07  Google Chrome Helper (Renderer)
# jettchen   85689  1.6 5065340  132768 ?             20:33   00:14  Google Chrome Helper (Renderer)
# jettchen   86098  2.1 5039264  175832 ?             20:43   00:05  Google Chrome Helper (Renderer)
# jettchen   86099  1.5 4951072  124324 ?             20:43   00:06  Google Chrome Helper (Renderer)
# jettchen   86624  1.5 4884460  128236 ?             20:55   00:06  Google Chrome Helper (Renderer)
# jettchen   86631  0.3 4726888   26236 ?             20:55   00:00  Google Chrome Helper (Renderer)
# jettchen   86790  0.2 4351284   13936 ?             21:00   00:00  CoreServicesUIAgent
# jettchen   86971  0.2 4321680   19448 ?             21:04   00:00  mdworker_shared
# jettchen   87123  2.0 5499144  164956 ?             21:06   00:30  WeChat
# jettchen   87131  0.1 4314612   12448 ?             21:06   00:00  mdworker_shared
# jettchen   87132  0.1 4314612   11760 ?             21:06   00:00  mdworker_shared
# jettchen   87133  0.2 4316448   16520 ?             21:06   00:00  mdworker_shared
# jettchen   87134  0.1 4314612   11576 ?             21:06   00:00  mdworker_shared
# jettchen   87135  0.1 4314612   11308 ?             21:06   00:00  mdworker_shared
# jettchen   87138  0.1 4314612   11344 ?             21:06   00:00  mdworker_shared
# jettchen   87139  0.1 4314612   11712 ?             21:06   00:00  mdworker_shared
# jettchen   87141  0.1 4314612   11556 ?             21:06   00:00  mdworker_shared
# jettchen   87142  0.1 4314612   11556 ?             21:06   00:00  mdworker_shared
# jettchen   87242  0.3 4321080   21272 ?             21:09   00:00  mdworker_shared
# root       87398    ?       ?       ? ?             21:14   00:00  automountd
# root       87416    ?       ?       ? ?             21:14   00:00  ocspd
# jettchen   87427  0.2 4333416   16312 ?             21:14   00:00  com.apple.iCloudHelper
# root       87493    ?       ?       ? ?             21:14   00:00  com.macpaw.Clean
# jettchen   87494  0.1 4331360    9828 ?             21:14   00:00  helpd
# jettchen   87537  0.6 4759444   50724 ?             21:15   00:00  Google Chrome Helper (Renderer)
# jettchen   87538  0.9 4788284   72808 ?             21:15   00:00  Google Chrome Helper (Renderer)
# jettchen   87543  0.2 4342176   13116 ?             21:15   00:00  mdworker
# _spotlight 87544    ?       ?       ? ?             21:15   00:00  mdworker

# %%
$pip show psutil
# Out:
#   File "<ipython-input-18-5e578c6f39f4>", line 1
#     $pip show psutil
#     ^
# SyntaxError: invalid syntax

# %%
help(psutil)
# Out:
# Help on package psutil:
#
# NAME
#     psutil
#
# DESCRIPTION
#     psutil is a cross-platform library for retrieving information on
#     running processes and system utilization (CPU, memory, disks, network,
#     sensors) in Python. Supported platforms:
#
#      - Linux
#      - Windows
#      - macOS
#      - FreeBSD
#      - OpenBSD
#      - NetBSD
#      - Sun Solaris
#      - AIX
#
#     Works with Python versions from 2.6 to 3.4+.
#
# PACKAGE CONTENTS
#     _common
#     _compat
#     _psaix
#     _psbsd
#     _pslinux
#     _psosx
#     _psposix
#     _pssunos
#     _psutil_osx
#     _psutil_posix
#     _pswindows
#     tests (package)
#
# SUBMODULES
#     _psplatform
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         Error
#             AccessDenied
#             NoSuchProcess
#                 ZombieProcess
#             TimeoutExpired
#     builtins.object
#         Process
#             Popen
#
#     class AccessDenied(Error)
#      |  AccessDenied(pid=None, name=None, msg=None)
#      |
#      |  Exception raised when permission to perform an action is denied.
#      |
#      |  Method resolution order:
#      |      AccessDenied
#      |      Error
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, pid=None, name=None, msg=None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from Error:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  __str__ = __repr__(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from Error:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class Error(builtins.Exception)
#      |  Error(msg='')
#      |
#      |  Base exception class. All other psutil exceptions inherit
#      |  from this one.
#      |
#      |  Method resolution order:
#      |      Error
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, msg='')
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  __str__ = __repr__(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class NoSuchProcess(Error)
#      |  NoSuchProcess(pid, name=None, msg=None)
#      |
#      |  Exception raised when a process with a certain PID doesn't
#      |  or no longer exists.
#      |
#      |  Method resolution order:
#      |      NoSuchProcess
#      |      Error
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, pid, name=None, msg=None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from Error:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  __str__ = __repr__(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from Error:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class Popen(Process)
#      |  Popen(*args, **kwargs)
#      |
#      |  A more convenient interface to stdlib subprocess.Popen class.
#      |      It starts a sub process and deals with it exactly as when using
#      |      subprocess.Popen class but in addition also provides all the
#      |      properties and methods of psutil.Process class as a unified
#      |      interface:
#      |
#      |        >>> import psutil
#      |        >>> from subprocess import PIPE
#      |        >>> p = psutil.Popen(["python", "-c", "print 'hi'"], stdout=PIPE)
#      |        >>> p.name()
#      |        'python'
#      |        >>> p.uids()
#      |        user(real=1000, effective=1000, saved=1000)
#      |        >>> p.username()
#      |        'giampaolo'
#      |        >>> p.communicate()
#      |        ('hi
#      |  ', None)
#      |        >>> p.terminate()
#      |        >>> p.wait(timeout=2)
#      |        0
#      |        >>>
#      |
#      |      For method names common to both classes such as kill(), terminate()
#      |      and wait(), psutil.Process implementation takes precedence.
#      |
#      |      Unlike subprocess.Popen this class pre-emptively checks whether PID
#      |      has been reused on send_signal(), terminate() and kill() so that
#      |      you don't accidentally terminate another process, fixing
#      |      http://bugs.python.org/issue6973.
#      |
#      |      For a complete documentation refer to:
#      |      http://docs.python.org/library/subprocess.html
#      |
#      |  Method resolution order:
#      |      Popen
#      |      Process
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __dir__(self)
#      |      Default dir() implementation.
#      |
#      |  __enter__(self)
#      |
#      |  __exit__(self, *args, **kwargs)
#      |
#      |  __getattribute__(self, name)
#      |      Return getattr(self, name).
#      |
#      |  __init__(self, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  wait(self, timeout=None)
#      |      Wait for process to terminate and, if process is a children
#      |      of os.getpid(), also return its exit code, else None.
#      |
#      |      If the process is already terminated immediately return None
#      |      instead of raising NoSuchProcess.
#      |
#      |      If *timeout* (in seconds) is specified and process is still
#      |      alive raise TimeoutExpired.
#      |
#      |      To wait for multiple Process(es) use psutil.wait_procs().
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from Process:
#      |
#      |  __eq__(self, other)
#      |      Return self==value.
#      |
#      |  __hash__(self)
#      |      Return hash(self).
#      |
#      |  __ne__(self, other)
#      |      Return self!=value.
#      |
#      |  __repr__ = __str__(self)
#      |
#      |  __str__(self)
#      |      Return str(self).
#      |
#      |  as_dict(self, attrs=None, ad_value=None)
#      |      Utility method returning process information as a
#      |      hashable dictionary.
#      |      If *attrs* is specified it must be a list of strings
#      |      reflecting available Process class' attribute names
#      |      (e.g. ['cpu_times', 'name']) else all public (read
#      |      only) attributes are assumed.
#      |      *ad_value* is the value which gets assigned in case
#      |      AccessDenied or ZombieProcess exception is raised when
#      |      retrieving that particular process information.
#      |
#      |  children(self, recursive=False)
#      |      Return the children of this process as a list of Process
#      |      instances, pre-emptively checking whether PID has been reused.
#      |      If *recursive* is True return all the parent descendants.
#      |
#      |      Example (A == this process):
#      |
#      |       A ─┐
#      |          │
#      |          ├─ B (child) ─┐
#      |          │             └─ X (grandchild) ─┐
#      |          │                                └─ Y (great grandchild)
#      |          ├─ C (child)
#      |          └─ D (child)
#      |
#      |      >>> import psutil
#      |      >>> p = psutil.Process()
#      |      >>> p.children()
#      |      B, C, D
#      |      >>> p.children(recursive=True)
#      |      B, X, Y, C, D
#      |
#      |      Note that in the example above if process X disappears
#      |      process Y won't be listed as the reference to process A
#      |      is lost.
#      |
#      |  cmdline(self)
#      |      The command line this process has been called with.
#      |
#      |  connections(self, kind='inet')
#      |      Return socket connections opened by process as a list of
#      |      (fd, family, type, laddr, raddr, status) namedtuples.
#      |      The *kind* parameter filters for connections that match the
#      |      following criteria:
#      |
#      |      +------------+----------------------------------------------------+
#      |      | Kind Value | Connections using                                  |
#      |      +------------+----------------------------------------------------+
#      |      | inet       | IPv4 and IPv6                                      |
#      |      | inet4      | IPv4                                               |
#      |      | inet6      | IPv6                                               |
#      |      | tcp        | TCP                                                |
#      |      | tcp4       | TCP over IPv4                                      |
#      |      | tcp6       | TCP over IPv6                                      |
#      |      | udp        | UDP                                                |
#      |      | udp4       | UDP over IPv4                                      |
#      |      | udp6       | UDP over IPv6                                      |
#      |      | unix       | UNIX socket (both UDP and TCP protocols)           |
#      |      | all        | the sum of all the possible families and protocols |
#      |      +------------+----------------------------------------------------+
#      |
#      |  cpu_percent(self, interval=None)
#      |      Return a float representing the current process CPU
#      |      utilization as a percentage.
#      |
#      |      When *interval* is 0.0 or None (default) compares process times
#      |      to system CPU times elapsed since last call, returning
#      |      immediately (non-blocking). That means that the first time
#      |      this is called it will return a meaningful 0.0 value.
#      |
#      |      When *interval* is > 0.0 compares process times to system CPU
#      |      times elapsed before and after the interval (blocking).
#      |
#      |      In this case is recommended for accuracy that this function
#      |      be called with at least 0.1 seconds between calls.
#      |
#      |      A value > 100.0 can be returned in case of processes running
#      |      multiple threads on different CPU cores.
#      |
#      |      The returned value is explicitly NOT split evenly between
#      |      all available logical CPUs. This means that a busy loop process
#      |      running on a system with 2 logical CPUs will be reported as
#      |      having 100% CPU utilization instead of 50%.
#      |
#      |      Examples:
#      |
#      |        >>> import psutil
#      |        >>> p = psutil.Process(os.getpid())
#      |        >>> # blocking
#      |        >>> p.cpu_percent(interval=1)
#      |        2.0
#      |        >>> # non-blocking (percentage since last call)
#      |        >>> p.cpu_percent(interval=None)
#      |        2.9
#      |        >>>
#      |
#      |  cpu_times(self)
#      |      Return a (user, system, children_user, children_system)
#      |      namedtuple representing the accumulated process time, in
#      |      seconds.
#      |      This is similar to os.times() but per-process.
#      |      On macOS and Windows children_user and children_system are
#      |      always set to 0.
#      |
#      |  create_time(self)
#      |      The process creation time as a floating point number
#      |      expressed in seconds since the epoch, in UTC.
#      |      The return value is cached after first call.
#      |
#      |  cwd(self)
#      |      Process current working directory as an absolute path.
#      |
#      |  environ(self)
#      |      The environment variables of the process as a dict.  Note: this
#      |      might not reflect changes made after the process started.
#      |
#      |  exe(self)
#      |      The process executable as an absolute path.
#      |      May also be an empty string.
#      |      The return value is cached after first call.
#      |
#      |  gids(self)
#      |      Return process GIDs as a (real, effective, saved)
#      |      namedtuple.
#      |
#      |  is_running(self)
#      |      Return whether this process is running.
#      |      It also checks if PID has been reused by another process in
#      |      which case return False.
#      |
#      |  kill(self)
#      |      Kill the current process with SIGKILL pre-emptively checking
#      |      whether PID has been reused.
#      |
#      |  memory_full_info(self)
#      |      This method returns the same information as memory_info(),
#      |      plus, on some platform (Linux, macOS, Windows), also provides
#      |      additional metrics (USS, PSS and swap).
#      |      The additional metrics provide a better representation of actual
#      |      process memory usage.
#      |
#      |      Namely USS is the memory which is unique to a process and which
#      |      would be freed if the process was terminated right now.
#      |
#      |      It does so by passing through the whole process address.
#      |      As such it usually requires higher user privileges than
#      |      memory_info() and is considerably slower.
#      |
#      |  memory_info(self)
#      |      Return a namedtuple with variable fields depending on the
#      |      platform, representing memory information about the process.
#      |
#      |      The "portable" fields available on all plaforms are `rss` and `vms`.
#      |
#      |      All numbers are expressed in bytes.
#      |
#      |  memory_info_ex(self)
#      |      memory_info_ex() is deprecated and will be removed; use memory_info() instead
#      |
#      |  memory_percent(self, memtype='rss')
#      |      Compare process memory to total physical system memory and
#      |      calculate process memory utilization as a percentage.
#      |      *memtype* argument is a string that dictates what type of
#      |      process memory you want to compare against (defaults to "rss").
#      |      The list of available strings can be obtained like this:
#      |
#      |      >>> psutil.Process().memory_info()._fields
#      |      ('rss', 'vms', 'shared', 'text', 'lib', 'data', 'dirty', 'uss', 'pss')
#      |
#      |  name(self)
#      |      The process name. The return value is cached after first call.
#      |
#      |  nice(self, value=None)
#      |      Get or set process niceness (priority).
#      |
#      |  num_ctx_switches(self)
#      |      Return the number of voluntary and involuntary context
#      |      switches performed by this process.
#      |
#      |  num_fds(self)
#      |      Return the number of file descriptors opened by this
#      |      process (POSIX only).
#      |
#      |  num_threads(self)
#      |      Return the number of threads used by this process.
#      |
#      |  oneshot(self)
#      |      Utility context manager which considerably speeds up the
#      |      retrieval of multiple process information at the same time.
#      |
#      |      Internally different process info (e.g. name, ppid, uids,
#      |      gids, ...) may be fetched by using the same routine, but
#      |      only one information is returned and the others are discarded.
#      |      When using this context manager the internal routine is
#      |      executed once (in the example below on name()) and the
#      |      other info are cached.
#      |
#      |      The cache is cleared when exiting the context manager block.
#      |      The advice is to use this every time you retrieve more than
#      |      one information about the process. If you're lucky, you'll
#      |      get a hell of a speedup.
#      |
#      |      >>> import psutil
#      |      >>> p = psutil.Process()
#      |      >>> with p.oneshot():
#      |      ...     p.name()  # collect multiple info
#      |      ...     p.cpu_times()  # return cached value
#      |      ...     p.cpu_percent()  # return cached value
#      |      ...     p.create_time()  # return cached value
#      |      ...
#      |      >>>
#      |
#      |  open_files(self)
#      |      Return files opened by process as a list of
#      |      (path, fd) namedtuples including the absolute file name
#      |      and file descriptor number.
#      |
#      |  parent(self)
#      |      Return the parent process as a Process object pre-emptively
#      |      checking whether PID has been reused.
#      |      If no parent is known return None.
#      |
#      |  parents(self)
#      |      Return the parents of this process as a list of Process
#      |      instances. If no parents are known return an empty list.
#      |
#      |  ppid(self)
#      |      The process parent PID.
#      |      On Windows the return value is cached after first call.
#      |
#      |  resume(self)
#      |      Resume process execution with SIGCONT pre-emptively checking
#      |      whether PID has been reused.
#      |      On Windows this has the effect of resuming all process threads.
#      |
#      |  send_signal(self, sig)
#      |      Send a signal *sig* to process pre-emptively checking
#      |      whether PID has been reused (see signal module constants) .
#      |      On Windows only SIGTERM is valid and is treated as an alias
#      |      for kill().
#      |
#      |  status(self)
#      |      The process current status as a STATUS_* constant.
#      |
#      |  suspend(self)
#      |      Suspend process execution with SIGSTOP pre-emptively checking
#      |      whether PID has been reused.
#      |      On Windows this has the effect ot suspending all process threads.
#      |
#      |  terminal(self)
#      |      The terminal associated with this process, if any,
#      |      else None.
#      |
#      |  terminate(self)
#      |      Terminate the process with SIGTERM pre-emptively checking
#      |      whether PID has been reused.
#      |      On Windows this is an alias for kill().
#      |
#      |  threads(self)
#      |      Return threads opened by process as a list of
#      |      (id, user_time, system_time) namedtuples representing
#      |      thread id and thread CPU times (user/system).
#      |      On OpenBSD this method requires root access.
#      |
#      |  uids(self)
#      |      Return process UIDs as a (real, effective, saved)
#      |      namedtuple.
#      |
#      |  username(self)
#      |      The name of the user that owns the process.
#      |      On UNIX this is calculated by using *real* process uid.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from Process:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  pid
#      |      The process PID.
#
#     class Process(builtins.object)
#      |  Process(pid=None)
#      |
#      |  Represents an OS process with the given PID.
#      |  If PID is omitted current process PID (os.getpid()) is used.
#      |  Raise NoSuchProcess if PID does not exist.
#      |
#      |  Note that most of the methods of this class do not make sure
#      |  the PID of the process being queried has been reused over time.
#      |  That means you might end up retrieving an information referring
#      |  to another process in case the original one this instance
#      |  refers to is gone in the meantime.
#      |
#      |  The only exceptions for which process identity is pre-emptively
#      |  checked and guaranteed are:
#      |
#      |   - parent()
#      |   - children()
#      |   - nice() (set)
#      |   - ionice() (set)
#      |   - rlimit() (set)
#      |   - cpu_affinity (set)
#      |   - suspend()
#      |   - resume()
#      |   - send_signal()
#      |   - terminate()
#      |   - kill()
#      |
#      |  To prevent this problem for all other methods you can:
#      |   - use is_running() before querying the process
#      |   - if you're continuously iterating over a set of Process
#      |     instances use process_iter() which pre-emptively checks
#      |   process identity for every yielded instance
#      |
#      |  Methods defined here:
#      |
#      |  __eq__(self, other)
#      |      Return self==value.
#      |
#      |  __hash__(self)
#      |      Return hash(self).
#      |
#      |  __init__(self, pid=None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __ne__(self, other)
#      |      Return self!=value.
#      |
#      |  __repr__ = __str__(self)
#      |
#      |  __str__(self)
#      |      Return str(self).
#      |
#      |  as_dict(self, attrs=None, ad_value=None)
#      |      Utility method returning process information as a
#      |      hashable dictionary.
#      |      If *attrs* is specified it must be a list of strings
#      |      reflecting available Process class' attribute names
#      |      (e.g. ['cpu_times', 'name']) else all public (read
#      |      only) attributes are assumed.
#      |      *ad_value* is the value which gets assigned in case
#      |      AccessDenied or ZombieProcess exception is raised when
#      |      retrieving that particular process information.
#      |
#      |  children(self, recursive=False)
#      |      Return the children of this process as a list of Process
#      |      instances, pre-emptively checking whether PID has been reused.
#      |      If *recursive* is True return all the parent descendants.
#      |
#      |      Example (A == this process):
#      |
#      |       A ─┐
#      |          │
#      |          ├─ B (child) ─┐
#      |          │             └─ X (grandchild) ─┐
#      |          │                                └─ Y (great grandchild)
#      |          ├─ C (child)
#      |          └─ D (child)
#      |
#      |      >>> import psutil
#      |      >>> p = psutil.Process()
#      |      >>> p.children()
#      |      B, C, D
#      |      >>> p.children(recursive=True)
#      |      B, X, Y, C, D
#      |
#      |      Note that in the example above if process X disappears
#      |      process Y won't be listed as the reference to process A
#      |      is lost.
#      |
#      |  cmdline(self)
#      |      The command line this process has been called with.
#      |
#      |  connections(self, kind='inet')
#      |      Return socket connections opened by process as a list of
#      |      (fd, family, type, laddr, raddr, status) namedtuples.
#      |      The *kind* parameter filters for connections that match the
#      |      following criteria:
#      |
#      |      +------------+----------------------------------------------------+
#      |      | Kind Value | Connections using                                  |
#      |      +------------+----------------------------------------------------+
#      |      | inet       | IPv4 and IPv6                                      |
#      |      | inet4      | IPv4                                               |
#      |      | inet6      | IPv6                                               |
#      |      | tcp        | TCP                                                |
#      |      | tcp4       | TCP over IPv4                                      |
#      |      | tcp6       | TCP over IPv6                                      |
#      |      | udp        | UDP                                                |
#      |      | udp4       | UDP over IPv4                                      |
#      |      | udp6       | UDP over IPv6                                      |
#      |      | unix       | UNIX socket (both UDP and TCP protocols)           |
#      |      | all        | the sum of all the possible families and protocols |
#      |      +------------+----------------------------------------------------+
#      |
#      |  cpu_percent(self, interval=None)
#      |      Return a float representing the current process CPU
#      |      utilization as a percentage.
#      |
#      |      When *interval* is 0.0 or None (default) compares process times
#      |      to system CPU times elapsed since last call, returning
#      |      immediately (non-blocking). That means that the first time
#      |      this is called it will return a meaningful 0.0 value.
#      |
#      |      When *interval* is > 0.0 compares process times to system CPU
#      |      times elapsed before and after the interval (blocking).
#      |
#      |      In this case is recommended for accuracy that this function
#      |      be called with at least 0.1 seconds between calls.
#      |
#      |      A value > 100.0 can be returned in case of processes running
#      |      multiple threads on different CPU cores.
#      |
#      |      The returned value is explicitly NOT split evenly between
#      |      all available logical CPUs. This means that a busy loop process
#      |      running on a system with 2 logical CPUs will be reported as
#      |      having 100% CPU utilization instead of 50%.
#      |
#      |      Examples:
#      |
#      |        >>> import psutil
#      |        >>> p = psutil.Process(os.getpid())
#      |        >>> # blocking
#      |        >>> p.cpu_percent(interval=1)
#      |        2.0
#      |        >>> # non-blocking (percentage since last call)
#      |        >>> p.cpu_percent(interval=None)
#      |        2.9
#      |        >>>
#      |
#      |  cpu_times(self)
#      |      Return a (user, system, children_user, children_system)
#      |      namedtuple representing the accumulated process time, in
#      |      seconds.
#      |      This is similar to os.times() but per-process.
#      |      On macOS and Windows children_user and children_system are
#      |      always set to 0.
#      |
#      |  create_time(self)
#      |      The process creation time as a floating point number
#      |      expressed in seconds since the epoch, in UTC.
#      |      The return value is cached after first call.
#      |
#      |  cwd(self)
#      |      Process current working directory as an absolute path.
#      |
#      |  environ(self)
#      |      The environment variables of the process as a dict.  Note: this
#      |      might not reflect changes made after the process started.
#      |
#      |  exe(self)
#      |      The process executable as an absolute path.
#      |      May also be an empty string.
#      |      The return value is cached after first call.
#      |
#      |  gids(self)
#      |      Return process GIDs as a (real, effective, saved)
#      |      namedtuple.
#      |
#      |  is_running(self)
#      |      Return whether this process is running.
#      |      It also checks if PID has been reused by another process in
#      |      which case return False.
#      |
#      |  kill(self)
#      |      Kill the current process with SIGKILL pre-emptively checking
#      |      whether PID has been reused.
#      |
#      |  memory_full_info(self)
#      |      This method returns the same information as memory_info(),
#      |      plus, on some platform (Linux, macOS, Windows), also provides
#      |      additional metrics (USS, PSS and swap).
#      |      The additional metrics provide a better representation of actual
#      |      process memory usage.
#      |
#      |      Namely USS is the memory which is unique to a process and which
#      |      would be freed if the process was terminated right now.
#      |
#      |      It does so by passing through the whole process address.
#      |      As such it usually requires higher user privileges than
#      |      memory_info() and is considerably slower.
#      |
#      |  memory_info(self)
#      |      Return a namedtuple with variable fields depending on the
#      |      platform, representing memory information about the process.
#      |
#      |      The "portable" fields available on all plaforms are `rss` and `vms`.
#      |
#      |      All numbers are expressed in bytes.
#      |
#      |  memory_info_ex(self)
#      |      memory_info_ex() is deprecated and will be removed; use memory_info() instead
#      |
#      |  memory_percent(self, memtype='rss')
#      |      Compare process memory to total physical system memory and
#      |      calculate process memory utilization as a percentage.
#      |      *memtype* argument is a string that dictates what type of
#      |      process memory you want to compare against (defaults to "rss").
#      |      The list of available strings can be obtained like this:
#      |
#      |      >>> psutil.Process().memory_info()._fields
#      |      ('rss', 'vms', 'shared', 'text', 'lib', 'data', 'dirty', 'uss', 'pss')
#      |
#      |  name(self)
#      |      The process name. The return value is cached after first call.
#      |
#      |  nice(self, value=None)
#      |      Get or set process niceness (priority).
#      |
#      |  num_ctx_switches(self)
#      |      Return the number of voluntary and involuntary context
#      |      switches performed by this process.
#      |
#      |  num_fds(self)
#      |      Return the number of file descriptors opened by this
#      |      process (POSIX only).
#      |
#      |  num_threads(self)
#      |      Return the number of threads used by this process.
#      |
#      |  oneshot(self)
#      |      Utility context manager which considerably speeds up the
#      |      retrieval of multiple process information at the same time.
#      |
#      |      Internally different process info (e.g. name, ppid, uids,
#      |      gids, ...) may be fetched by using the same routine, but
#      |      only one information is returned and the others are discarded.
#      |      When using this context manager the internal routine is
#      |      executed once (in the example below on name()) and the
#      |      other info are cached.
#      |
#      |      The cache is cleared when exiting the context manager block.
#      |      The advice is to use this every time you retrieve more than
#      |      one information about the process. If you're lucky, you'll
#      |      get a hell of a speedup.
#      |
#      |      >>> import psutil
#      |      >>> p = psutil.Process()
#      |      >>> with p.oneshot():
#      |      ...     p.name()  # collect multiple info
#      |      ...     p.cpu_times()  # return cached value
#      |      ...     p.cpu_percent()  # return cached value
#      |      ...     p.create_time()  # return cached value
#      |      ...
#      |      >>>
#      |
#      |  open_files(self)
#      |      Return files opened by process as a list of
#      |      (path, fd) namedtuples including the absolute file name
#      |      and file descriptor number.
#      |
#      |  parent(self)
#      |      Return the parent process as a Process object pre-emptively
#      |      checking whether PID has been reused.
#      |      If no parent is known return None.
#      |
#      |  parents(self)
#      |      Return the parents of this process as a list of Process
#      |      instances. If no parents are known return an empty list.
#      |
#      |  ppid(self)
#      |      The process parent PID.
#      |      On Windows the return value is cached after first call.
#      |
#      |  resume(self)
#      |      Resume process execution with SIGCONT pre-emptively checking
#      |      whether PID has been reused.
#      |      On Windows this has the effect of resuming all process threads.
#      |
#      |  send_signal(self, sig)
#      |      Send a signal *sig* to process pre-emptively checking
#      |      whether PID has been reused (see signal module constants) .
#      |      On Windows only SIGTERM is valid and is treated as an alias
#      |      for kill().
#      |
#      |  status(self)
#      |      The process current status as a STATUS_* constant.
#      |
#      |  suspend(self)
#      |      Suspend process execution with SIGSTOP pre-emptively checking
#      |      whether PID has been reused.
#      |      On Windows this has the effect ot suspending all process threads.
#      |
#      |  terminal(self)
#      |      The terminal associated with this process, if any,
#      |      else None.
#      |
#      |  terminate(self)
#      |      Terminate the process with SIGTERM pre-emptively checking
#      |      whether PID has been reused.
#      |      On Windows this is an alias for kill().
#      |
#      |  threads(self)
#      |      Return threads opened by process as a list of
#      |      (id, user_time, system_time) namedtuples representing
#      |      thread id and thread CPU times (user/system).
#      |      On OpenBSD this method requires root access.
#      |
#      |  uids(self)
#      |      Return process UIDs as a (real, effective, saved)
#      |      namedtuple.
#      |
#      |  username(self)
#      |      The name of the user that owns the process.
#      |      On UNIX this is calculated by using *real* process uid.
#      |
#      |  wait(self, timeout=None)
#      |      Wait for process to terminate and, if process is a children
#      |      of os.getpid(), also return its exit code, else None.
#      |
#      |      If the process is already terminated immediately return None
#      |      instead of raising NoSuchProcess.
#      |
#      |      If *timeout* (in seconds) is specified and process is still
#      |      alive raise TimeoutExpired.
#      |
#      |      To wait for multiple Process(es) use psutil.wait_procs().
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  pid
#      |      The process PID.
#
#     class TimeoutExpired(Error)
#      |  TimeoutExpired(seconds, pid=None, name=None)
#      |
#      |  Raised on Process.wait(timeout) if timeout expires and process
#      |  is still alive.
#      |
#      |  Method resolution order:
#      |      TimeoutExpired
#      |      Error
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, seconds, pid=None, name=None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from Error:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  __str__ = __repr__(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from Error:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class ZombieProcess(NoSuchProcess)
#      |  ZombieProcess(pid, name=None, ppid=None, msg=None)
#      |
#      |  Exception raised when querying a zombie process. This is
#      |  raised on macOS, BSD and Solaris only, and not always: depending
#      |  on the query the OS may be able to succeed anyway.
#      |  On Linux all zombie processes are querable (hence this is never
#      |  raised). Windows doesn't have zombie processes.
#      |
#      |  Method resolution order:
#      |      ZombieProcess
#      |      NoSuchProcess
#      |      Error
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, pid, name=None, ppid=None, msg=None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from Error:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  __str__ = __repr__(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from Error:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
# FUNCTIONS
#     boot_time()
#         Return the system boot time expressed in seconds since the epoch.
#
#     cpu_count(logical=True)
#         Return the number of logical CPUs in the system (same as
#         os.cpu_count() in Python 3.4).
#
#         If *logical* is False return the number of physical cores only
#         (e.g. hyper thread CPUs are excluded).
#
#         Return None if undetermined.
#
#         The return value is cached after first call.
#         If desired cache can be cleared like this:
#
#         >>> psutil.cpu_count.cache_clear()
#
#     cpu_freq(percpu=False)
#         Return CPU frequency as a nameduple including current,
#         min and max frequency expressed in Mhz.
#
#         If *percpu* is True and the system supports per-cpu frequency
#         retrieval (Linux only) a list of frequencies is returned for
#         each CPU. If not a list with one element is returned.
#
#     cpu_percent(interval=None, percpu=False)
#         Return a float representing the current system-wide CPU
#         utilization as a percentage.
#
#         When *interval* is > 0.0 compares system CPU times elapsed before
#         and after the interval (blocking).
#
#         When *interval* is 0.0 or None compares system CPU times elapsed
#         since last call or module import, returning immediately (non
#         blocking). That means the first time this is called it will
#         return a meaningless 0.0 value which you should ignore.
#         In this case is recommended for accuracy that this function be
#         called with at least 0.1 seconds between calls.
#
#         When *percpu* is True returns a list of floats representing the
#         utilization as a percentage for each CPU.
#         First element of the list refers to first CPU, second element
#         to second CPU and so on.
#         The order of the list is consistent across calls.
#
#         Examples:
#
#           >>> # blocking, system-wide
#           >>> psutil.cpu_percent(interval=1)
#           2.0
#           >>>
#           >>> # blocking, per-cpu
#           >>> psutil.cpu_percent(interval=1, percpu=True)
#           [2.0, 1.0]
#           >>>
#           >>> # non-blocking (percentage since last call)
#           >>> psutil.cpu_percent(interval=None)
#           2.9
#           >>>
#
#     cpu_stats()
#         Return CPU statistics.
#
#     cpu_times(percpu=False)
#         Return system-wide CPU times as a namedtuple.
#         Every CPU time represents the seconds the CPU has spent in the
#         given mode. The namedtuple's fields availability varies depending on the
#         platform:
#
#          - user
#          - system
#          - idle
#          - nice (UNIX)
#          - iowait (Linux)
#          - irq (Linux, FreeBSD)
#          - softirq (Linux)
#          - steal (Linux >= 2.6.11)
#          - guest (Linux >= 2.6.24)
#          - guest_nice (Linux >= 3.2.0)
#
#         When *percpu* is True return a list of namedtuples for each CPU.
#         First element of the list refers to first CPU, second element
#         to second CPU and so on.
#         The order of the list is consistent across calls.
#
#     cpu_times_percent(interval=None, percpu=False)
#         Same as cpu_percent() but provides utilization percentages
#         for each specific CPU time as is returned by cpu_times().
#         For instance, on Linux we'll get:
#
#           >>> cpu_times_percent()
#           cpupercent(user=4.8, nice=0.0, system=4.8, idle=90.5, iowait=0.0,
#                      irq=0.0, softirq=0.0, steal=0.0, guest=0.0, guest_nice=0.0)
#           >>>
#
#         *interval* and *percpu* arguments have the same meaning as in
#         cpu_percent().
#
#     disk_io_counters(perdisk=False, nowrap=True)
#         Return system disk I/O statistics as a namedtuple including
#         the following fields:
#
#          - read_count:  number of reads
#          - write_count: number of writes
#          - read_bytes:  number of bytes read
#          - write_bytes: number of bytes written
#          - read_time:   time spent reading from disk (in ms)
#          - write_time:  time spent writing to disk (in ms)
#
#         Platform specific:
#
#          - busy_time: (Linux, FreeBSD) time spent doing actual I/Os (in ms)
#          - read_merged_count (Linux): number of merged reads
#          - write_merged_count (Linux): number of merged writes
#
#         If *perdisk* is True return the same information for every
#         physical disk installed on the system as a dictionary
#         with partition names as the keys and the namedtuple
#         described above as the values.
#
#         If *nowrap* is True it detects and adjust the numbers which overflow
#         and wrap (restart from 0) and add "old value" to "new value" so that
#         the returned numbers will always be increasing or remain the same,
#         but never decrease.
#         "disk_io_counters.cache_clear()" can be used to invalidate the
#         cache.
#
#         On recent Windows versions 'diskperf -y' command may need to be
#         executed first otherwise this function won't find any disk.
#
#     disk_partitions(all=False)
#         Return mounted partitions as a list of
#         (device, mountpoint, fstype, opts) namedtuple.
#         'opts' field is a raw string separated by commas indicating mount
#         options which may vary depending on the platform.
#
#         If *all* parameter is False return physical devices only and ignore
#         all others.
#
#     disk_usage(path)
#         Return disk usage statistics about the given *path* as a
#         namedtuple including total, used and free space expressed in bytes
#         plus the percentage usage.
#
#     net_connections(kind='inet')
#         Return system-wide socket connections as a list of
#         (fd, family, type, laddr, raddr, status, pid) namedtuples.
#         In case of limited privileges 'fd' and 'pid' may be set to -1
#         and None respectively.
#         The *kind* parameter filters for connections that fit the
#         following criteria:
#
#         +------------+----------------------------------------------------+
#         | Kind Value | Connections using                                  |
#         +------------+----------------------------------------------------+
#         | inet       | IPv4 and IPv6                                      |
#         | inet4      | IPv4                                               |
#         | inet6      | IPv6                                               |
#         | tcp        | TCP                                                |
#         | tcp4       | TCP over IPv4                                      |
#         | tcp6       | TCP over IPv6                                      |
#         | udp        | UDP                                                |
#         | udp4       | UDP over IPv4                                      |
#         | udp6       | UDP over IPv6                                      |
#         | unix       | UNIX socket (both UDP and TCP protocols)           |
#         | all        | the sum of all the possible families and protocols |
#         +------------+----------------------------------------------------+
#
#         On macOS this function requires root privileges.
#
#     net_if_addrs()
#         Return the addresses associated to each NIC (network interface
#         card) installed on the system as a dictionary whose keys are the
#         NIC names and value is a list of namedtuples for each address
#         assigned to the NIC. Each namedtuple includes 5 fields:
#
#          - family: can be either socket.AF_INET, socket.AF_INET6 or
#                    psutil.AF_LINK, which refers to a MAC address.
#          - address: is the primary address and it is always set.
#          - netmask: and 'broadcast' and 'ptp' may be None.
#          - ptp: stands for "point to point" and references the
#                 destination address on a point to point interface
#                 (typically a VPN).
#          - broadcast: and *ptp* are mutually exclusive.
#
#         Note: you can have more than one address of the same family
#         associated with each interface.
#
#     net_if_stats()
#         Return information about each NIC (network interface card)
#         installed on the system as a dictionary whose keys are the
#         NIC names and value is a namedtuple with the following fields:
#
#          - isup: whether the interface is up (bool)
#          - duplex: can be either NIC_DUPLEX_FULL, NIC_DUPLEX_HALF or
#                    NIC_DUPLEX_UNKNOWN
#          - speed: the NIC speed expressed in mega bits (MB); if it can't
#                   be determined (e.g. 'localhost') it will be set to 0.
#          - mtu: the maximum transmission unit expressed in bytes.
#
#     net_io_counters(pernic=False, nowrap=True)
#         Return network I/O statistics as a namedtuple including
#         the following fields:
#
#          - bytes_sent:   number of bytes sent
#          - bytes_recv:   number of bytes received
#          - packets_sent: number of packets sent
#          - packets_recv: number of packets received
#          - errin:        total number of errors while receiving
#          - errout:       total number of errors while sending
#          - dropin:       total number of incoming packets which were dropped
#          - dropout:      total number of outgoing packets which were dropped
#                          (always 0 on macOS and BSD)
#
#         If *pernic* is True return the same information for every
#         network interface installed on the system as a dictionary
#         with network interface names as the keys and the namedtuple
#         described above as the values.
#
#         If *nowrap* is True it detects and adjust the numbers which overflow
#         and wrap (restart from 0) and add "old value" to "new value" so that
#         the returned numbers will always be increasing or remain the same,
#         but never decrease.
#         "disk_io_counters.cache_clear()" can be used to invalidate the
#         cache.
#
#     pid_exists(pid)
#         Return True if given PID exists in the current process list.
#         This is faster than doing "pid in psutil.pids()" and
#         should be preferred.
#
#     pids()
#         Return a list of current running PIDs.
#
#     process_iter(attrs=None, ad_value=None)
#         Return a generator yielding a Process instance for all
#         running processes.
#
#         Every new Process instance is only created once and then cached
#         into an internal table which is updated every time this is used.
#
#         Cached Process instances are checked for identity so that you're
#         safe in case a PID has been reused by another process, in which
#         case the cached instance is updated.
#
#         The sorting order in which processes are yielded is based on
#         their PIDs.
#
#         *attrs* and *ad_value* have the same meaning as in
#         Process.as_dict(). If *attrs* is specified as_dict() is called
#         and the resulting dict is stored as a 'info' attribute attached
#         to returned Process instance.
#         If *attrs* is an empty list it will retrieve all process info
#         (slow).
#
#     sensors_battery()
#         Return battery information. If no battery is installed
#         returns None.
#
#          - percent: battery power left as a percentage.
#          - secsleft: a rough approximation of how many seconds are left
#                      before the battery runs out of power. May be
#                      POWER_TIME_UNLIMITED or POWER_TIME_UNLIMITED.
#          - power_plugged: True if the AC power cable is connected.
#
#     swap_memory()
#         Return system swap memory statistics as a namedtuple including
#         the following fields:
#
#          - total:   total swap memory in bytes
#          - used:    used swap memory in bytes
#          - free:    free swap memory in bytes
#          - percent: the percentage usage
#          - sin:     no. of bytes the system has swapped in from disk (cumulative)
#          - sout:    no. of bytes the system has swapped out from disk (cumulative)
#
#         'sin' and 'sout' on Windows are meaningless and always set to 0.
#
#     users()
#         Return users currently connected on the system as a list of
#         namedtuples including the following fields.
#
#          - user: the name of the user
#          - terminal: the tty or pseudo-tty associated with the user, if any.
#          - host: the host name associated with the entry, if any.
#          - started: the creation time as a floating point number expressed in
#            seconds since the epoch.
#
#     virtual_memory()
#         Return statistics about system memory usage as a namedtuple
#         including the following fields, expressed in bytes:
#
#          - total:
#            total physical memory available.
#
#          - available:
#            the memory that can be given instantly to processes without the
#            system going into swap.
#            This is calculated by summing different memory values depending
#            on the platform and it is supposed to be used to monitor actual
#            memory usage in a cross platform fashion.
#
#          - percent:
#            the percentage usage calculated as (total - available) / total * 100
#
#          - used:
#             memory used, calculated differently depending on the platform and
#             designed for informational purposes only:
#             macOS: active + inactive + wired
#             BSD: active + wired + cached
#             Linux: total - free
#
#          - free:
#            memory not being used at all (zeroed) that is readily available;
#            note that this doesn't reflect the actual memory available
#            (use 'available' instead)
#
#         Platform-specific fields:
#
#          - active (UNIX):
#            memory currently in use or very recently used, and so it is in RAM.
#
#          - inactive (UNIX):
#            memory that is marked as not used.
#
#          - buffers (BSD, Linux):
#            cache for things like file system metadata.
#
#          - cached (BSD, macOS):
#            cache for various things.
#
#          - wired (macOS, BSD):
#            memory that is marked to always stay in RAM. It is never moved to disk.
#
#          - shared (BSD):
#            memory that may be simultaneously accessed by multiple processes.
#
#         The sum of 'used' and 'available' does not necessarily equal total.
#         On Windows 'available' and 'free' are the same.
#
#     wait_procs(procs, timeout=None, callback=None)
#         Convenience function which waits for a list of processes to
#         terminate.
#
#         Return a (gone, alive) tuple indicating which processes
#         are gone and which ones are still alive.
#
#         The gone ones will have a new *returncode* attribute indicating
#         process exit status (may be None).
#
#         *callback* is a function which gets called every time a process
#         terminates (a Process instance is passed as callback argument).
#
#         Function will return as soon as all processes terminate or when
#         *timeout* occurs.
#         Differently from Process.wait() it will not raise TimeoutExpired if
#         *timeout* occurs.
#
#         Typical use case is:
#
#          - send SIGTERM to a list of processes
#          - give them some time to terminate
#          - send SIGKILL to those ones which are still alive
#
#         Example:
#
#         >>> def on_terminate(proc):
#         ...     print("process {} terminated".format(proc))
#         ...
#         >>> for p in procs:
#         ...    p.terminate()
#         ...
#         >>> gone, alive = wait_procs(procs, timeout=3, callback=on_terminate)
#         >>> for p in alive:
#         ...     p.kill()
#
# DATA
#     AF_LINK = 18
#     AIX = False
#     BSD = False
#     CONN_CLOSE = 'CLOSE'
#     CONN_CLOSE_WAIT = 'CLOSE_WAIT'
#     CONN_CLOSING = 'CLOSING'
#     CONN_ESTABLISHED = 'ESTABLISHED'
#     CONN_FIN_WAIT1 = 'FIN_WAIT1'
#     CONN_FIN_WAIT2 = 'FIN_WAIT2'
#     CONN_LAST_ACK = 'LAST_ACK'
#     CONN_LISTEN = 'LISTEN'
#     CONN_NONE = 'NONE'
#     CONN_SYN_RECV = 'SYN_RECV'
#     CONN_SYN_SENT = 'SYN_SENT'
#     CONN_TIME_WAIT = 'TIME_WAIT'
#     FREEBSD = False
#     LINUX = False
#     MACOS = True
#     NETBSD = False
#     NIC_DUPLEX_FULL = <NicDuplex.NIC_DUPLEX_FULL: 2>
#     NIC_DUPLEX_HALF = <NicDuplex.NIC_DUPLEX_HALF: 1>
#     NIC_DUPLEX_UNKNOWN = <NicDuplex.NIC_DUPLEX_UNKNOWN: 0>
#     OPENBSD = False
#     OSX = True
#     POSIX = True
#     POWER_TIME_UNKNOWN = <BatteryTime.POWER_TIME_UNKNOWN: -1>
#     POWER_TIME_UNLIMITED = <BatteryTime.POWER_TIME_UNLIMITED: -2>
#     STATUS_DEAD = 'dead'
#     STATUS_DISK_SLEEP = 'disk-sleep'
#     STATUS_IDLE = 'idle'
#     STATUS_LOCKED = 'locked'
#     STATUS_PARKED = 'parked'
#     STATUS_RUNNING = 'running'
#     STATUS_SLEEPING = 'sleeping'
#     STATUS_STOPPED = 'stopped'
#     STATUS_TRACING_STOP = 'tracing-stop'
#     STATUS_WAITING = 'waiting'
#     STATUS_WAKING = 'waking'
#     STATUS_ZOMBIE = 'zombie'
#     SUNOS = False
#     WINDOWS = False
#     __all__ = ['Error', 'NoSuchProcess', 'ZombieProcess', 'AccessDenied', ...
#     version_info = (5, 6, 1)
#
# VERSION
#     5.6.1
#
# AUTHOR
#     Giampaolo Rodola'
#
# FILE
#     /anaconda3/lib/python3.7/site-packages/psutil/__init__.py

# %%
users = psutil.users()
type(users)
# Out:
# list

# %%
print(users)
for u in users:
    print(u.name)
# Out:
# [suser(name='jettchen', terminal='console', host=None, started=1568985344.0, pid=94), suser(name='jettchen', terminal='ttys000', host=None, started=1569498496.0, pid=83431), suser(name='jettchen', terminal='ttys002', host=None, started=1569499520.0, pid=84308)]
# jettchen
# jettchen
# jettchen

# %%
psutil.cpu_count()
# Out:
# 4

# %%
psutil.cpu_count(logical=False)
# Out:
# 2

# %%
psutil.cpu_times_percent()
# Out:
# scputimes(user=8.7, nice=0.0, system=8.4, idle=83.0)

# %%
mem = psutil.virtual_memory()
type(mem)
# Out:
# psutil._psosx.svmem

# %%
mem.total
# print(type(mem.total))
# Out:
# 8589934592

# %%
mem.available
# Out:
# 2893938688

# %%
mem.percent
# Out:
# 66.3

# %%
mem.percent
# Out:
# 66.3

# %%
mem.total
# Out:
# 8589934592

# %%
mem.avaliable
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-65d6b402886a> in <module>
# ----> 1 mem.avaliable
#
# AttributeError: 'svmem' object has no attribute 'avaliable'

# %%
mem.available
# Out:
# 2893938688

# %%
disk = psutil.disk_partitions()
type(disk)
# Out:
# list

# %%
print(disk)
# Out:
# [sdiskpart(device='/dev/disk1s1', mountpoint='/', fstype='apfs', opts='rw,local,rootfs,dovolfs,journaled,multilabel'), sdiskpart(device='/dev/disk1s4', mountpoint='/private/var/vm', fstype='apfs', opts='rw,noexec,local,dovolfs,dontbrowse,journaled,multilabel,noatime')]

# %%
nd = disk[0]
print(nd.device)
print(nd.mountpoint)
print(nd.fstype)
print(nd.opts)
# Out:
# /dev/disk1s1
# /
# apfs
# rw,local,rootfs,dovolfs,journaled,multilabel

# %%
len(disk)
# Out:
# 3
